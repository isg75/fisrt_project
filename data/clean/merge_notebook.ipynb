# %% [markdown]
# ## Merging DataFrames

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

employment_df = pd.read_csv('./employment_df.csv')
hdi_df = pd.read_csv('./hdi_clean.csv')
rd_extended_df = pd.read_csv('./RD_extended_df.csv')
patents_df = pd.read_csv('./patents_data_clean.csv')

# %% [markdown]
# ### Employment DataFrame

# %%
print('\nemployment_df:\n')
display(employment_df)
print('\ndata types per column:\n')
print(employment_df.dtypes)
# Out:
# employment_df:
#       country_code            area  year              statistic_type  \
# 0                1           World  2005  Labour force participation
# 1                1           World  2005           Unemployment rate
# 2                1           World  2010  Labour force participation
# 3                1           World  2010           Unemployment rate
# 4                1           World  2015  Labour force participation
# ...            ...             ...   ...                         ...
# 1833            97  European Union  2010           Unemployment rate
# 1834            97  European Union  2015  Labour force participation
# 1835            97  European Union  2015           Unemployment rate
# 1836            97  European Union  2023  Labour force participation
# 1837            97  European Union  2023           Unemployment rate
#
#       statistic_value
# 0                62.9
# 1                 6.3
# 2                62.0
# 3                 6.3
# 4                60.7
# ...               ...
# 1833              9.8
# 1834             56.8
# 1835             10.0
# 1836             57.6
# 1837              6.3
#
# [1838 rows x 5 columns]
# data types per column:
#
# country_code         int64
# area                object
# year                 int64
# statistic_type      object
# statistic_value    float64
# dtype: object

# %%
print('\nmissing values per column:\n')
print(employment_df.isnull().sum())
# Out:
# missing values per column:
#
# country_code       0
# area               0
# year               0
# statistic_type     0
# statistic_value    0
# dtype: int64

# %% [markdown]
# ### HDI (Human Development Index) DataFrame

# %%
print('\n hdi_df: \n')
hdi_df.rename(columns={'iso3':'country_iso', 'country':'area'}, inplace=True)
display(hdi_df)
print('\ndata types per column:\n')
print(hdi_df.dtypes)
# Out:
#  hdi_df:
#      country_iso                  area human_development_groups  \
# 0            AFG           Afghanistan                      Low
# 1            AGO                Angola                   Medium
# 2            ALB               Albania                     High
# 3            AND               Andorra                Very High
# 4            ARE  United Arab Emirates                Very High
# ...          ...                   ...                      ...
# 4285         WSM                 Samoa                     High
# 4286         YEM                 Yemen                      Low
# 4287         ZAF          South Africa                     High
# 4288         ZMB                Zambia                   Medium
# 4289         ZWE              Zimbabwe                   Medium
#
#      undp_developing_regions  year  human_development_index_(hdi)
# 0                         SA  2000                          0.335
# 1                        SSA  2000                          0.375
# 2                        ECA  2000                          0.677
# 3                        NaN  2000                          0.818
# 4                         AS  2000                          0.796
# ...                      ...   ...                            ...
# 4285                     EAP  2021                          0.707
# 4286                      AS  2021                          0.455
# 4287                     SSA  2021                          0.713
# 4288                     SSA  2021                          0.565
# 4289                     SSA  2021                          0.593
#
# [4290 rows x 6 columns]
# data types per column:
#
# country_iso                       object
# area                              object
# human_development_groups          object
# undp_developing_regions           object
# year                               int64
# human_development_index_(hdi)    float64
# dtype: object

# %%
print('\nmissing values per column:\n')
print(hdi_df.isnull().sum())
# Out:
# missing values per column:
#
# country_iso                        0
# area                               0
# human_development_groups          88
# undp_developing_regions          968
# year                               0
# human_development_index_(hdi)    189
# dtype: int64

# %% [markdown]
# ### Patents DataFrame

# %%
print('\nrd_extended_df:\n')
rd_extended_df.rename(columns={'location':'country_iso'}, inplace=True)
display(rd_extended_df)
print('\ndata types per column:\n')
print(rd_extended_df.dtypes)
# Out:
# rd_extended_df:
#                   area  year  \
# 0                World  2005
# 1                World  2005
# 2                World  2010
# 3                World  2010
# 4                World  2015
# ...                ...   ...
# 1751         Venezuela  2016
# 1752  Papua New Guinea  2016
# 1753       Ivory Coast  2016
# 1754            Angola  2016
# 1755        Mauritania  2018
#
#                                                  series       value  \
# 0     Gross domestic expenditure on R&D: as a percen...     1.50000
# 1             Researchers per million inhabitants (FTE)   907.20000
# 2     Gross domestic expenditure on R&D: as a percen...     1.60000
# 3             Researchers per million inhabitants (FTE)  1022.10000
# 4     Gross domestic expenditure on R&D: as a percen...     1.70000
# ...                                                 ...         ...
# 1751                                                NaN     0.69000
# 1752                                                NaN     0.03158
# 1753                                                NaN     0.06975
# 1754                                                NaN     0.03229
# 1755                                                NaN     0.01019
#
#      country_iso  country_code
# 0            NaN           1.0
# 1            NaN           1.0
# 2            NaN           1.0
# 3            NaN           1.0
# 4            NaN           1.0
# ...          ...           ...
# 1751         VEN           NaN
# 1752         PNG           NaN
# 1753         CIV           NaN
# 1754         AGO           NaN
# 1755         MRT           NaN
#
# [1756 rows x 6 columns]
# data types per column:
#
# area             object
# year              int64
# series           object
# value           float64
# country_iso      object
# country_code    float64
# dtype: object

# %%
print('\nmissing values per column:\n')
print(rd_extended_df.isnull().sum())
# Out:
# missing values per column:
#
# area              0
# year              0
# series          773
# value             0
# country_iso     983
# country_code    773
# dtype: int64

# %% [markdown]
# ### Extended R&D DataFrame:

# %%
print('\npatents_df:\n')
patents_df.rename(columns={'region': 'country_code', 'country':'area'}, inplace=True)
display(patents_df)
print('\ndata types per column:\n')
print(patents_df.dtypes)
# Out:
# patents_df:
#       country_code                           area  year  \
# 0                1  Total, all countries or areas  1985
# 1                1  Total, all countries or areas  1995
# 2                1  Total, all countries or areas  2005
# 3                1  Total, all countries or areas  2010
# 4                1  Total, all countries or areas  2019
# ...            ...                            ...   ...
# 1855           716                       Zimbabwe  2020
# 1856           716                       Zimbabwe  2021
# 1857           716                       Zimbabwe  2019
# 1858           716                       Zimbabwe  2020
# 1859           716                       Zimbabwe  2021
#
#                          patents  number_patents  patents_mapped
# 0     Grants of patents (number)             NaN               1
# 1     Grants of patents (number)             NaN               1
# 2     Grants of patents (number)             NaN               1
# 3     Grants of patents (number)             NaN               1
# 4     Grants of patents (number)             NaN               1
# ...                          ...             ...             ...
# 1855  Grants of patents (number)             6.0               1
# 1856  Grants of patents (number)            10.0               1
# 1857   Patents in force (number)            14.0               3
# 1858   Patents in force (number)             4.0               3
# 1859   Patents in force (number)             4.0               3
#
# [1860 rows x 6 columns]
# data types per column:
#
# country_code        int64
# area               object
# year                int64
# patents            object
# number_patents    float64
# patents_mapped      int64
# dtype: object

# %%
print('\nmissing values per column:\n')
print(patents_df.isnull().sum())
# Out:
# missing values per column:
#
# country_code        0
# area                0
# year                0
# patents             0
# number_patents    615
# patents_mapped      0
# dtype: int64
