# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/clean/final_df.csv')

df.head()
df
# Out:
#      Unnamed: 0            area  year            gdp  r_d  researchers    hdi  \
# 0             0      Azerbaijan  2021    54825411765  0.2       1741.1  0.745
# 1             1       Argentina  2005   198737000000  0.4        819.4  0.802
# 2             2       Argentina  2010   423627000000  0.6       1123.8  0.834
# 3             3       Argentina  2020   385741000000  0.5       1236.9  0.840
# 4             4       Australia  2010  1148890000000  2.4       4532.4  0.923
# ..          ...             ...   ...            ...  ...          ...    ...
# 101         101           Egypt  2010   218984000000  0.4        492.4  0.675
# 102         102  United Kingdom  2005  2543180000000  1.5       4123.5  0.895
# 103         103  United Kingdom  2010  2485480000000  1.6       4043.3  0.912
# 104         104  United Kingdom  2019  2851410000000  1.7       4683.8  0.935
# 105         105      Uzbekistan  2021    69600614987  0.1        523.4  0.727
#
# ...

# %%
df['area'].unique()
# Out:
# array(['Azerbaijan', 'Argentina', 'Australia', 'Austria', 'Belgium',
#        'Brazil', 'Bulgaria', 'Belarus', 'Canada', 'Sri Lanka', 'Chile',
#        'China', 'Costa Rica', 'Croatia', 'Cyprus', 'Czechia', 'Denmark',
#        'Ecuador', 'El Salvador', 'Estonia', 'Finland', 'France',
#        'Georgia', 'Germany', 'Greece', 'Guatemala', 'Hungary', 'Iceland',
#        'India', 'Ireland', 'Italy', 'Japan', 'Kazakhstan', 'Kenya',
#        'Latvia', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malaysia',
#        'Malta', 'Mauritius', 'Mexico', 'New Zealand', 'Norway',
#        'Pakistan', 'Philippines', 'Poland', 'Portugal', 'Romania',
#        'Serbia', 'Singapore', 'Slovenia', 'South Africa', 'Spain',
#        'Sweden', 'Switzerland', 'Thailand', 'United Arab Emirates',
#        'Tunisia', 'Ukraine', 'Egypt', 'United Kingdom', 'Uzbekistan'],
#       dtype=object)

# %%
european_countries = [
    'Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia', 
    'Denmark', 'Estonia', 'Finland', 'France', 'Georgia', 'Germany', 
    'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 
    'Lithuania', 'Luxembourg', 'Malta', 'Norway', 'Poland', 'Portugal', 
    'Romania', 'Serbia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 
    'Ukraine', 'United Kingdom'
]

# %% [markdown]
# ### Create new dataframe only with the countries in the above list
# - Drop 'Unnamed: 0' column
# - Reset index

# %%
eu_df = df[df['area'].isin(european_countries)]
eu_df = eu_df.drop('Unnamed: 0', axis=1) # this one was a repeated column with the index numbers
eu_df = eu_df.reset_index(drop=True)

eu_df
# Out:
#               area  year            gdp  r_d  researchers    hdi  \
# 0          Austria  2005   316092000000  2.4       3449.3  0.889
# 1          Austria  2010   392275000000  2.7       4349.7  0.902
# 2          Belgium  2005   385715000000  1.8       3142.7  0.902
# 3          Belgium  2010   481421000000  2.1       3732.8  0.912
# 4         Bulgaria  2005    29868657858  0.4       1307.8  0.762
# 5         Bulgaria  2010    50760929303  0.6       1478.7  0.790
# 6          Croatia  2005    45025679590  0.8       1308.1  0.802
# 7          Croatia  2010    58836405999  0.7       1641.3  0.821
# 8           Cyprus  2005    18433411267  0.4        916.7  0.834
# 9           Cyprus  2010    25799940416  0.4       1077.7  0.857
# 10         Czechia  2005   137143000000  1.2       2356.1  0.844
# 11         Czechia  2010   209070000000  1.3       2774.0  0.870
# 12         Denmark  2005   264467000000  2.4       5197.4  0.911
# ...

# %%
print(eu_df.dtypes) #check data types
# Out:
# area                             object
# year                              int64
# gdp                               int64
# r_d                             float64
# researchers                     float64
# hdi                             float64
# public_expenditure_education    float64
# patents_num                       int64
# dtype: object

# %% [markdown]
# ### Calculate correlation between R&D and HDI
# - `.corr()` computes the linear relationship between variables
# 1. Group data by 'area'
# 2. calculate the correlation using .corr()

# %%
# Filter the dataset based on non-zero standard deviations for 'r_d' and 'hdi'
df_clean = eu_df.groupby('area').filter(lambda x: x['r_d'].std() > 0 and x['hdi'].std() > 0)

# Calculate correlation for each 'area'
country_correlations = df_clean.groupby('area')[['r_d', 'hdi']].apply(lambda x: x['r_d'].corrcoef(x['hdi']))

# reset index for easier merge
country_correlations = country_correlations.reset_index(name='rd_hdi_correlation')

# merge correlation values back
final_df = pd.merge(df_clean, country_correlations, on='area', how='left')

# Drop duplicates if you only want one row per 'area' and 'year'
# final_df = final_df.drop_duplicates(subset=['area', 'year'])

# round correlations to 2 decimal
final_df['rd_hdi_correlation'] = final_df['rd_hdi_correlation'].round(3)

# keep relevant columns
final_df = final_df[['area', 'year', 'r_d', 'hdi', 'rd_hdi_correlation']]
final_df

# that took a minute, but that's the result (decimals rounded to 3)
# I'm happy to share the code because I found very weird that all give 1 or -1
# yes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6068/792379702.py in ?()
#       1 # Filter the dataset based on non-zero standard deviations for 'r_d' and 'hdi'
#       2 df_clean = eu_df.groupby('area').filter(lambda x: x['r_d'].std() > 0 and x['hdi'].std() > 0)
#       3
#       4 # Calculate correlation for each 'area'
# ----> 5 country_correlations = df_clean.groupby('area')[['r_d', 'hdi']].apply(lambda x: x['r_d'].corrcoef(x['hdi']))
#       6
#       7 # reset index for easier merge
#       8 country_correlations = country_correlations.reset_index(name='rd_hdi_correlation')
#
# ~/Code/ironhack/week-3/first_project/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py in ?(self, func, include_groups, *args, **kwargs)
#    1833                         ),
#    1834                         category=DeprecationWarning,
# ...

# %% [markdown]
# ### Line Plot with Facets by Country (Area)

# %%
sns.set(style="whitegrid")

# create a line plot
g = sns.FacetGrid(final_df, col="area", col_wrap=4, height=4)
g.map(sns.lineplot, "year", "r_d", color="blue", label="R&D Spending")
g.map(sns.lineplot, "year", "hdi", color="orange", label="HDI")

g.add_legend()
plt.show()

# %% [markdown]
# ### Scatter Plot: R&D vs HDI for Each Year

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=eu_df, x='r_d', y='hdi', hue='area', palette="viridis", style='year', s=150)
plt.title('R&D vs HDI (Color-coded by Year)')
plt.xlabel('R&D Investment')
plt.ylabel('Human Development Index')
plt.legend(title='Year')
plt.show()

# %% [markdown]
# ### Heatmap of `rd_hdi_correlation Across Countries and Years

# %%
# Pivot data to get correlation by country and year
correlation_pivot = eu_df.pivot_table(values='rd_hdi_correlation', index='area', columns='year')

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_pivot, annot=True, cmap='Spectral', center=0, fmt='.2f')
plt.title('R&D vs HDI Correlation by Country and Year')
plt.xlabel('Year')
plt.ylabel('Country')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Pivot data to get correlation by country and year
# ----> 2 correlation_pivot = eu_df.pivot_table(values='rd_hdi_correlation', index='area', columns='year')
#       4 plt.figure(figsize=(12, 8))
#       5 sns.heatmap(correlation_pivot, annot=True, cmap='Spectral', center=0, fmt='.2f')
#
# File ~/Code/ironhack/week-3/first_project/.venv/lib/python3.12/site-packages/pandas/core/frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
# ...

# %% [markdown]
# ### Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a pivoted DataFrame where we have countries as rows and the years as columns for r_d and hdi
df_pivot_r_d = eu_df.pivot_table(index='area', columns='year', values='r_d')
df_pivot_hdi = eu_df.pivot_table(index='area', columns='year', values='hdi')

# Combine the two DataFrames (r_d and hdi) into one
df_combined = pd.concat([df_pivot_r_d, df_pivot_hdi], axis=1, keys=['r_d', 'hdi'])

# Calculate the correlation matrix for the combined DataFrame
corr = df_combined.corr()

# Set the size of the figure
plt.figure(figsize=(14, 10))

# Create the heatmap using a nicer color palette (viridis, cividis, etc.)
sns.heatmap(corr, annot=True, cmap='viridis', fmt='.2f', linewidths=1, linecolor='black', cbar=True)

# Title and axis labels
plt.title('Heatmap: Correlation between R&D, HDI, and Year by Country', fontsize=16)
plt.xlabel('Year and Variable', fontsize=12)
plt.ylabel('Country', fontsize=12)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)
# Make sure the country names are visible and not rotated
plt.yticks(rotation=0)

# Display the plot
plt.show()

### the funny thing is that when I generated the maps, SOMEHOW the numbers are different???
# we might need to double check the .corr() function then, it might not be the right way of doing it.
# also some countries were returning NaN 
# .corr() theoretically returns the linear correlation between values, but 
# I was trying to display the country names here, that's what I was doing when the call started. I can work further in it.
#It should? We'll see.

# %%
### Clustermap

# %%
# Pivot the dataframe to have years as rows and countries as columns for R&D and HDI
df_pivot = eu_df.pivot_table(index='year', columns='area', values=['r_d', 'hdi'])

# Clustermap
sns.clustermap(df_pivot, cmap='coolwarm', method='ward', figsize=(12, 8), annot=True)
plt.title('Clustermap: Correlation of R&D and HDI by Country and Year', y=1.05)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 5
#       2 df_pivot = eu_df.pivot_table(index='year', columns='area', values=['r_d', 'hdi'])
#       4 # Clustermap
# ----> 5 sns.clustermap(df_pivot, cmap='coolwarm', method='ward', figsize=(12, 8), annot=True)
#       6 plt.title('Clustermap: Correlation of R&D and HDI by Country and Year', y=1.05)
#       7 plt.show()
#
# File ~/Code/ironhack/week-3/first_project/.venv/lib/python3.12/site-packages/seaborn/matrix.py:1250, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1157 """
#    1158 Plot a matrix dataset as a hierarchically-clustered heatmap.
#    1159
#    (...)
#    1247
#    1248 """
#    1249 if _no_scipy:
# ...

# %%
### Jointplot

# %%
plt.figure(figsize=(10, 6))

# Agg Dodge using categorical plot for R&D and HDI
sns.catplot(data=eu_df, x='year', y='r_d', hue='area', kind='strip', dodge=True, height=6, aspect=2)

plt.title('Agg Dodge: R&D Spending by Country and Year')
plt.xlabel('Year')
plt.ylabel('R&D Spending')
plt.xticks(rotation=45)
plt.show()

# HDI Plot
sns.catplot(data=eu_df, x='year', y='hdi', hue='area', kind='strip', dodge=True, height=6, aspect=2)

plt.title('Agg Dodge: HDI by Country and Year')
plt.xlabel('Year')
plt.ylabel('Human Development Index')
plt.xticks(rotation=45)
plt.show()

# %%
# I also don't know, I might try with 3 or 4 countries. seaborn has different palettes but can be confusing

plt.figure(figsize=(10, 6))

# Stripplot to visualize R&D vs Area (Country)
sns.stripplot(data=eu_df, x='area', y='r_d', jitter=True, palette='summer', size=10, alpha=0.7)

plt.title('Stripplot: R&D Spending by Country')
plt.xlabel('Country')
plt.ylabel('R&D Spending')
plt.xticks(rotation=90)  # Rotate country names for better visibility
plt.show()
# Out:
# /tmp/ipykernel_98065/990621834.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=eu_df, x='area', y='r_d', jitter=True, palette='summer', size=10, alpha=0.7)

# %% [markdown]
# That's the spending by country, and I like it quite a lot bc you can see the country names. The color is a gradient, unsure how clear it is but

# %%
Thank you!
# Out:
#   Cell In[24], line 1
#     Thank you!
#           ^
# SyntaxError: invalid syntax

# %%
LOL - so I will go home during lunch and then I can finally talk. For the afternoon I would first do the slides and then
# Out:
#   Cell In[25], line 1
#     LOL - so I will go home during lunch and then I can finally talk. For the afternoon I would first do the slides and then
#              ^
# SyntaxError: invalid syntax

# %%
jesus
continue this. okay?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 jesus
#       2 get_ipython().run_line_magic('pinfo', 'okay')
#
# NameError: name 'jesus' is not defined

# %%
THANK YOU
